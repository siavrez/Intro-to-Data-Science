# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm


x_axis = np.arange(85, 115, 0.1)
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
plt.figure(figsize=(10,6))
plt.plot(x_axis, norm.pdf(x_axis,100,scale=15/np.sqrt(30)), lw=3)
plt.axvline(x=112, color="r", lw=3, label=r"$\mu=112$")
plt.xlabel("IQ scores", fontsize=20)
plt.ylabel("Density", fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.legend( fontsize=20)

# %%
x_axis
# Out:
# array([  80.   ,   80.001,   80.002, ...,  119.997,  119.998,  119.999])

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.mlab as mlab
import math

mu = 100
variance = 15
sigma = 15
x = np.linspace(mu-3*sigma,mu+3*sigma, 100)
plt.plot(x,mlab.normpdf(x, mu, sigma))

plt.show()

# %%
15/np.sqrt(30)
# Out:
# 2.7386127875258306

# %%
12 / 2.74
# Out:
# 4.37956204379562
